# %% [markdown]
# # Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data

# %%
stocks = pd.read_csv("../../data/stocks.csv", index_col=0, parse_dates=True)
stocks
# Out:
#            Company      Sector        Open        High         Low  \
# Date
# 2017-11-02    AAPL  Technology   41.650002   42.125000   41.320000
# 2017-11-03    AAPL  Technology   43.500000   43.564999   42.779999
# 2017-11-06    AAPL  Technology   43.092499   43.747501   42.930000
# 2017-11-07    AAPL  Technology   43.477501   43.812500   43.400002
# 2017-11-08    AAPL  Technology   43.665001   44.060001   43.582500
# ...            ...         ...         ...         ...         ...
# 2022-10-26     COP      Energy  124.720001  128.179993  124.580002
# 2022-10-27     COP      Energy  127.699997  129.449997  126.239998
# 2022-10-28     COP      Energy  128.500000  128.990005  124.010002
# 2022-10-31     COP      Energy  125.580002  129.990005  125.570000
# 2022-11-01     COP      Energy  128.740005  129.320007  126.889999
#
#                  Close     Volume
# Date
# 2017-11-02   42.027500  165573600
# 2017-11-03   43.125000  237594400
# 2017-11-06   43.562500  140105200
# 2017-11-07   43.702499   97446000
# 2017-11-08   44.060001   97638000
# ...                ...        ...
# 2022-10-26  126.570000    8139100
# 2022-10-27  126.639999    8948500
# 2022-10-28  127.169998    7293200
# 2022-10-31  126.089996    7121000
# 2022-11-01  127.779999    5874800
#
# [63377 rows x 7 columns]

# %% [markdown]
# ## Trend of Closing Prices

# %%
sectors = stocks["Sector"].unique()
sectors.sort()
sectors
# Out:
# array(['Communication Services', 'Consumer Cyclical', 'Energy',
#        'Financial Services', 'Healthcare', 'Industrials', 'Technology'],
#       dtype=object)

# %%
def plot_closing_price(sector):
    
    plt.figure(figsize=(16, 8))
    
    df = stocks[stocks["Sector"] == sector]
    df = df[df.index >= "2020-01-01"]

    for company in df["Company"].unique():
        closing_price = df[df["Company"] == company]["Close"]
        plt.plot(closing_price, label=company)
    
    plt.title(sector)
    plt.ylabel("Closing Price")
    plt.legend()
    plt.grid()
    plt.show()

# %%
plot_closing_price(sectors[0])

# %%
plot_closing_price(sectors[1])

# %%
plot_closing_price(sectors[2])

# %%
plot_closing_price(sectors[3])

# %%
plot_closing_price(sectors[4])

# %%
plot_closing_price(sectors[5])

# %%
plot_closing_price(sectors[6])

# %% [markdown]
# ## Evaluate Companies by Dollar Volumes

# %% [markdown]
# The **Dollar Volume** can be computed by
#
# $$
# \text{Dollar Volume} = \text{Closing Price} \times \text{Volume}
# $$

# %% [markdown]
# Find the company with maximum *average* dollar volume in each sector:

# %%
df = stocks.copy()
df["Dollar Volume"] = stocks["Close"] * stocks["Volume"]
df.groupby(["Company", "Sector"]).mean()\
    .sort_values("Dollar Volume", ascending=False)\
    .reset_index(level=(0, 1))\
    .drop_duplicates(["Sector"])\
    .set_index("Sector").sort_index()
# Out:
#                        Company        Open        High         Low  \
# Sector
# Communication Services    META  220.025342  223.021956  217.089746
# Consumer Cyclical         TSLA  127.043256  129.981087  123.856482
# Energy                     XOM   68.634610   69.379531   67.892830
# Financial Services         BAC   32.411455   32.780286   32.036796
# Healthcare                 UNH  332.256829  335.852615  328.694006
# Industrials                 BA  262.930366  266.543116  259.027941
# Technology                AAPL   94.844223   95.986419   93.766286
#
#                              Close        Volume  Dollar Volume
# Sector
# Communication Services  220.069316  2.337455e+07   4.929304e+09
# Consumer Cyclical       126.995117  1.317317e+08   1.306260e+10
# Energy                   68.636971  2.044632e+07   1.327712e+09
# Financial Services       32.406224  5.806661e+07   1.825491e+09
# Healthcare              332.375851  3.532888e+06   1.128240e+09
# Industrials             262.674833  1.174971e+07   2.541470e+09
# Technology               94.923971  1.178255e+08   1.039713e+10
